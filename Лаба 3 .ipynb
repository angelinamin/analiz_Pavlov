# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Тема-3.-Функции" data-toc-modified-id="Тема-3.-Функции-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Тема 3. Функции</a></span></li><li><span><a href="#Задания" data-toc-modified-id="Задания-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Задания</a></span></li></ul></div>

# %% [markdown]
# # Тема 3. Функции

# %% [markdown]
# # Задания
#
# Выполните задания

# %% [markdown]
# 1. Имеется список из 20 случайных чисел от 0 до 100. Напишите функцию, которая разбивает этот список на $n$ списков по $k$ элементов и включает все эти списки в новый список. Используйте $k$ в качестве параметра функции.
#
# 2. Напишите функцию, вычисляющую факториал числа, передаваемого в качестве параметра.
#
# 3. Написать функцию умножения, принимающую от одного до трех параметров. Функцию вызвать с приведенными ниже аргументами. Для случая a4 выбрать 3 первых и 3 последних значения.
# ```
# a1 = (15, 10 ,5)
# a2 = (3, 1)
# a3 = [2, 35, 55]
# a4 = (5, 10 ,15, 20)
# ```
#
# 4. Напишите функцию, которая для заданного радиуса r вычисляет площадь круга и длину окружности. Функция возвращает кортеж из 2 значений.
#
# 5. Реализовать функции для выполнения четырех арифметических операций, преобразующих целые числа в целое число. Создать словарь с функциями исоответствующими им симв олами операций. Для двух заранее заданных целых чисел (например, 25 и 4) выполнить выбранную пользователем арифметическую операцию.
#
# 6. Написать калькулятор для строковых выражений вида '<число> <операция> <число>', где <число> - целое число, например 113, <арифметическая операция> - одна из операций `+,-,*,//,%,^`. Пример: `calc('13 - 5') -> 8`
#
# 7. Написать функцию, которая преобразует целое число (от 0 до 999) из текстового представления на русском языке в число типа int. Пример: `to_int('тридцать три') -> 33`
#
# 8. Написать функцию, которая преобразует целое число (от 0 до 999) из текстового представления на русском языке в число типа int. И сообщает об ошибках (выводит на экран описание типа ошибки и возвращает число -1). Пример: to_int('тридцать три') -> 33 Пример: to_int("сто сорок тридцать два сто") -> -1 Вывод: тридцать - некорректное расположение в числе.

# %% [markdown]
# Имеется список из 20 случайных чисел от 0 до 100. Напишите функцию, которая разбивает этот список на  𝑛
#   списков по  𝑘
#   элементов и включает все эти списки в новый список. Используйте  𝑘
#   в качестве параметра функции.

# %% [markdown]
#  ### 1.Имеется список из 20 случайных чисел от 0 до 100. Напишите функцию, которая разбивает этот список на  𝑛 списков по 𝑘 элементов и включает все эти списки в новый список. Используйте  𝑘 в качестве параметра функции.

# %%
import random 

def разбить_список(исходный_список, k): 
   
    
    подсписки = [исходный_список[i:i+k] for i in range(0, len(исходный_список), k)] 
  
    
    return подсписки 
исходный_список = [random.randint(0, 100) for _ in range(20)]


k = 5  
результат = разбить_список(исходный_список, k)  

print(результат)
# Out:
# [[15, 3, 24, 91, 100], [29, 85, 70, 85, 16], [93, 93, 81, 21, 62], [37, 86, 80, 89, 3]]

# %% [markdown]
# 2.Напишите функцию, вычисляющую факториал числа, передаваемого в качестве параметра.

# %%
def factorial(n):
    result = 1
    
    for i in range(1, n + 1):
        result *= i
        
    return result

n = int(input("Введите число n: "))
result = factorial(n)

print(f"Факториал числа {n} равен {result}")
# Out:
# Введите число n: 6
# Факториал числа 6 равен 0

# %% [markdown]
# 3.Написать функцию умножения, принимающую от одного до трех параметров. Функцию вызвать с приведенными ниже аргументами. Для случая a4 выбрать 3 первых и 3 последних значения.
#
# a1 = (15, 10 ,5)
# a2 = (3, 1)
# a3 = [2, 35, 55]
# a4 = (5, 10 ,15, 20)

# %%
def multiplication(a, b=None, c=None):
   
    result = 1  
    if a is not None:
        result *= a  
        result *= b  
    if c is not None:
        result *= c 
    return result 

a1 = (15, 10, 5)  
a2 = (3, 1)  
a3 = [2, 35, 55]  
a4 = (5, 10, 15, 20) 

result_a1 = multiplication(*a1)  
result_a2 = multiplication(*a2)  
result_a3 = multiplication(*a3)  
result_a4_first = multiplication(*a4[:3])
result_a4_last = multiplication(*a4[-3:])


print("Результат умножения  a1:", result_a1)
print("Результат умножения  a2:", result_a2)
print("Результат умножения  a3:", result_a3)
print("Результат умножения первых трех значений  a4:", result_a4_first)
print("Результат умножения последних трех значений  a4:", result_a4_last)
# Out:
# Результат умножения  a1: 750
# Результат умножения  a2: 3
# Результат умножения  a3: 3850
# Результат умножения первых трех значений  a4: 750
# Результат умножения последних трех значений  a4: 3000

# %% [markdown]
# 4.Напишите функцию, которая для заданного радиуса r вычисляет площадь круга и длину окружности. Функция возвращает кортеж из 2 значений.

# %%
import math

def  calculate_circle_properties():
    #площадь
    square = math.pi * radius**2
     #длина
    circumference_length = 2 * math.pi * radius

    return (square, circumference_length)


result = calculate_circle_properties()

radius = float(input("Введите радиус круга: "))

print(f"Площадь круга: {result[0]}, Длина окружности: {result[1]}")
# Out:
# Введите радиус круга: 5
# Площадь круга: 78.53981633974483, Длина окружности: 31.41592653589793

# %% [markdown]
#  5.Реализовать функции для выполнения четырех арифметических операций, преобразующих целые числа в целое число. Создать словарь с функциями исоответствующими им символами операций. Для двух заранее заданных целых чисел (например, 25 и 4) выполнить выбранную пользователем арифметическую операцию.

# %%
def add(x, y):
    return x + y

def subtract(x, y):
    return x - y

def multiplication(x, y):
    return x * y

def divide(x, y):
    if y == 0:
        return "Деление на ноль недопустимо"
    return x / y

#словарь
operations = {
    '+': add,
    '-': subtract,
    '*': multiplication,
    '/': divide
}




operation_symbol = input("Введите символ  (+, -, *, /): ")

num1 = int(input("Введите первое число: "))
num2 = int(input("Введите второе число: "))

if operation_symbol in operations:
   
    result = operations[operation_symbol](num1, num2)
   
    print(f"Результат {num1} {operation_symbol} {num2} = {result}")
   
else:
    print("Некорректный символ.")
# Out:
# Введите символ  (+, -, *, /): +
# Введите первое число: 7
# Введите второе число: 5
# Результат 7 + 5 = 12

# %% [markdown]
# 6.Написать калькулятор для строковых выражений вида '<число> <операция> <число>', где <число> - целое число, например 113, <арифметическая операция> - одна из операций +,-,*,//,%,^. Пример: calc('13 - 5') -> 8

# %%
def calc(term):

    components = term.split()  
    chislo1 = float(components[0]) 
    operation = components[1]
    chislo2 = float(components[2]) 

    
    if operation == '+':
        result = chislo1 + chislo2
    elif operation == '-':
        result = chislo1 - chislo2
    elif operation == '*':
        result = chislo1 * chislo2
    elif operation == '//':
        # Деление с округлением 
        if chislo2 != 0:
            result = chislo1 // chislo2
        else:
            result = "Ошибка: деление на ноль"
    elif operation == '%':
        result = chislo1 % chislo2
    elif operation == '^':
        result = chislo1 ** chislo2
    else:
        result = "Ошибка: неподдерживаемая операция"

    return result

term = input("Введите выражение в формате 'число1 операция число2': ")
result = calc(term)
print(f"Результат выражения '{term}': {result}")
# Out:
# Введите выражение в формате 'число1 операция число2': 4 * 6
# Результат выражения '4 * 6': 24.0

# %% [markdown]
# 7.Написать функцию, которая преобразует целое число (от 0 до 999) из текстового представления на русском языке в число типа int. Пример: to_int('тридцать три') -> 33

# %%
def to_int(текст):
    
    
    числительные = {
        'ноль': 0, 'один': 1, 'два': 2, 'три': 3, 'четыре': 4,
        'пять': 5, 'шесть': 6, 'семь': 7, 'восемь': 8, 'девять': 9,
        'десять': 10, 'одиннадцать': 11, 'двенадцать': 12, 'тринадцать': 13, 'четырнадцать': 14,
        'пятнадцать': 15, 'шестнадцать': 16, 'семнадцать': 17, 'восемнадцать': 18, 'девятнадцать': 19,
        'двадцать': 20, 'тридцать': 30, 'сорок': 40, 'пятьдесят': 50,
        'шестьдесят': 60, 'семьдесят': 70, 'восемьдесят': 80, 'девяносто': 90,
        'сто': 100, 'двести': 200, 'триста': 300, 'четыреста': 400, 'пятьсот': 500,
        'шестьсот': 600, 'семьсот': 700, 'восемьсот': 800, 'девятьсот': 900
    }

   
    слова = текст.split()

    текущее_число = 0
    общий_результат = 0

    for слово in слова:
        if слово in числительные:
            текущее_число += числительные[слово]  
        else:
            текущее_число = 0

  
    общий_результат += текущее_число

    return общий_результат


ваш_текст = input("Введите текстовое представление числа (на русском языке): ")
результат = to_int(ваш_текст)
print(f"Преобразованное число из текста '{ваш_текст}': {результат}")

# %% [markdown]
# 8.Написать функцию, которая преобразует целое число (от 0 до 999) из текстового представления на русском языке в число типа int. И сообщает об ошибках (выводит на экран описание типа ошибки и возвращает число -1). Пример: to_int('тридцать три') -> 33 Пример: to_int("сто сорок тридцать два сто") -> -1 Вывод: тридцать - некорректное расположение в числе.

# %%
def to_int(текст):
    числительные = {
        'ноль': 0, 'один': 1, 'два': 2, 'три': 3, 'четыре': 4,
        'пять': 5, 'шесть': 6, 'семь': 7, 'восемь': 8, 'девять': 9,
        'десять': 10, 'одиннадцать': 11, 'двенадцать': 12, 'тринадцать': 13, 'четырнадцать': 14,
        'пятнадцать': 15, 'шестнадцать': 16, 'семнадцать': 17, 'восемнадцать': 18, 'девятнадцать': 19,
        'двадцать': 20, 'тридцать': 30, 'сорок': 40, 'пятьдесят': 50,
        'шестьдесят': 60, 'семьдесят': 70, 'восемьдесят': 80, 'девяносто': 90,
        'сто': 100, 'двести': 200, 'триста': 300, 'четыреста': 400, 'пятьсот': 500,
        'шестьсот': 600, 'семьсот': 700, 'восемьсот': 800, 'девятьсот': 900
    }

  
    слова = текст.split()


    текущее_число = 0
    общий_результат = 0

    for слово in слова:
        if слово in числительные:
            текущее_число += числительные[слово]
        else:
            print(f"Ошибка: '{слово}' - некорректное слово в числе.")
            return -1

   
    общий_результат += текущее_число

    return общий_результат


ваш_текст = input("Введите текстовое представление числа (на русском языке): ")
результат = to_int(ваш_текст)

if результат != -1:
    print(f"Преобразованное число из текста '{ваш_текст}': {результат}")
else:
    print("Произошла ошибка. Пожалуйста, проверьте ввод.")
# Out:
# Введите текстовое представление числа (на русском языке): пять
# Преобразованное число из текста 'пять': 5
